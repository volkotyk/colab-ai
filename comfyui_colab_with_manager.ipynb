# ********** ERROR ***********
#
# comfyui-workflow-templates is not installed.
#
# Please install the updated requirements.txt file by running:
# /usr/bin/python3 -m pip install -r /content/drive/MyDrive/ComfyUI/requirements.txt
# If you are on the portable package you can run: update\update_comfyui.bat to solve this problem.
#
# This error is happening because the ComfyUI frontend is no longer shipped as part of the main repo but as a pip package instead.
#
# ********** ERROR ***********
# comfyui-embedded-docs package not found
# ------------------------------------------------------------------------
# Error importing dependencies: No module named 'alembic'
# Please install the updated requirements.txt file by running:
# /usr/bin/python3 -m pip install -r /content/drive/MyDrive/ComfyUI/requirements.txt
# If you are on the portable package you can run: update\update_comfyui.bat to solve this problem.
# This error is happening because ComfyUI now uses a local sqlite database.
# ------------------------------------------------------------------------
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
#
# ComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)
#
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# FETCH ComfyRegistry Data: 5/92
# This is the URL to access ComfyUI: https://modular-consumption-per-toolbar.trycloudflare.com                                 |
# FETCH ComfyRegistry Data: 10/92
# FETCH ComfyRegistry Data: 15/92
# FETCH ComfyRegistry Data: 20/92
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
#
# Stopped server
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/main.py", line 356, in <module>
#     event_loop.run_until_complete(x)
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1898, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/main.py", line 358, in <module>
#     logging.info("\nStopped server")
#   File "/usr/lib/python3.11/logging/__init__.py", line 2141, in info
#     root.info(msg, *args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1489, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1634, in _log
#     self.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1644, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1706, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 978, in handle
#     self.emit(record)
#   File "/content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/prestartup_script.py", line 427, in emit
#     stderr_wrapper.sync_write(message+'\n', file_only=True)
#   File "/content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/prestartup_script.py", line 343, in sync_write
#     log_file.flush()
# KeyboardInterrupt
# Cannot connect to comfyregistry.
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json[ComfyUI-Manager] Due to a network error, switching to local mode.
# => custom-node-list.json
# => cannot schedule new futures after shutdown
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.

# %%
# !wget -P ~ https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i ~/cloudflared-linux-amd64.deb
!

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
# Out:
# --2025-07-21 05:05:49--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.7.0/cloudflared-linux-amd64.deb [following]
# --2025-07-21 05:05:49--  https://github.com/cloudflare/cloudflared/releases/download/2025.7.0/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/71a18481-c0d4-48a3-92f7-c052c62a8b60?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-21T05%3A55%3A21Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-21T04%3A54%3A53Z&ske=2025-07-21T05%3A55%3A21Z&sks=b&skv=2018-11-09&sig=t0keHsR5Dz9i%2Bn7Vwoh01JzaI%2BWtokCnqhApj0zF6F4%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MzA3NDY0OSwibmJmIjoxNzUzMDc0MzQ5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.uz_j1OTKbTbIZ1FYmP3hpbLpdICbMTOK5SZo76djmzM&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream [following]
# --2025-07-21 05:05:49--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/71a18481-c0d4-48a3-92f7-c052c62a8b60?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-21T05%3A55%3A21Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-21T04%3A54%3A53Z&ske=2025-07-21T05%3A55%3A21Z&sks=b&skv=2018-11-09&sig=t0keHsR5Dz9i%2Bn7Vwoh01JzaI%2BWtokCnqhApj0zF6F4%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MzA3NDY0OSwibmJmIjoxNzUzMDc0MzQ5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.uz_j1OTKbTbIZ1FYmP3hpbLpdICbMTOK5SZo76djmzM&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20166246 (19M) [application/octet-stream]
# Saving to: ‘/root/cloudflared-linux-amd64.deb.1’
#
# cloudflared-linux-a 100%[===================>]  19.23M   113MB/s    in 0.2s
#
# 2025-07-21 05:05:49 (113 MB/s) - ‘/root/cloudflared-linux-amd64.deb.1’ saved [20166246/20166246]
#
# (Reading database ... 126285 files and directories currently installed.)
# Preparing to unpack .../cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2025.7.0) over (2025.7.0) ...
# Setting up cloudflared (2025.7.0) ...
# Processing triggers for man-db (2.10.2-1) ...
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-21 05:05:52.744
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    1.4 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.44
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 2124, in load_custom_node
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/drive/MyDrive/ComfyUI/comfy_extras/nodes_audio.py", line 3, in <module>
#     import av
# ModuleNotFoundError: No module named 'av'
#
# Cannot import /content/drive/MyDrive/ComfyUI/comfy_extras/nodes_audio.py module for custom nodes: No module named 'av'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 2124, in load_custom_node
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/drive/MyDrive/ComfyUI/comfy_extras/nodes_lt.py", line 10, in <module>
#     import av
# ModuleNotFoundError: No module named 'av'
#
# Cannot import /content/drive/MyDrive/ComfyUI/comfy_extras/nodes_lt.py module for custom nodes: No module named 'av'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 2124, in load_custom_node
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/drive/MyDrive/ComfyUI/comfy_extras/nodes_load_3d.py", line 6, in <module>
#     from comfy_api.input_impl import VideoFromFile
#   File "/content/drive/MyDrive/ComfyUI/comfy_api/input_impl/__init__.py", line 1, in <module>
#     from .video_types import VideoFromFile, VideoFromComponents
#   File "/content/drive/MyDrive/ComfyUI/comfy_api/input_impl/video_types.py", line 2, in <module>
#     from av.container import InputContainer
# ModuleNotFoundError: No module named 'av'
#
# Cannot import /content/drive/MyDrive/ComfyUI/comfy_extras/nodes_load_3d.py module for custom nodes: No module named 'av'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 2124, in load_custom_node
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/drive/MyDrive/ComfyUI/comfy_extras/nodes_video.py", line 4, in <module>
#     import av
# ModuleNotFoundError: No module named 'av'
#
# Cannot import /content/drive/MyDrive/ComfyUI/comfy_extras/nodes_video.py module for custom nodes: No module named 'av'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 2124, in load_custom_node
#     module_spec.loader.exec_module(module)
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/content/drive/MyDrive/ComfyUI/comfy_api_nodes/canary.py", line 1, in <module>
#     import av
# ModuleNotFoundError: No module named 'av'
#
# Cannot import /content/drive/MyDrive/ComfyUI/comfy_api_nodes/canary.py module for custom nodes: No module named 'av'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
# ### Loading: ComfyUI-Manager (V3.34.1)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.44-32-g7d627f76 | Released on '2025-07-20'
# Unable to parse pyproject.toml due to lack dependency pydantic-settings, please run 'pip install -r requirements.txt': No module named 'pydantic_settings'
#
# Import times for custom nodes:
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# WARNING: some comfy_api_nodes/ nodes did not import correctly. This may be because they are missing some dependencies.
#
# IMPORT FAILED: nodes_ideogram.py
# IMPORT FAILED: nodes_openai.py
# IMPORT FAILED: nodes_minimax.py
# IMPORT FAILED: nodes_veo2.py
# IMPORT FAILED: nodes_kling.py
# IMPORT FAILED: nodes_bfl.py
# IMPORT FAILED: nodes_luma.py
# IMPORT FAILED: nodes_recraft.py
# IMPORT FAILED: nodes_pixverse.py
# IMPORT FAILED: nodes_stability.py
# IMPORT FAILED: nodes_pika.py
# IMPORT FAILED: nodes_runway.py
# IMPORT FAILED: nodes_tripo.py
# IMPORT FAILED: nodes_moonvalley.py
# IMPORT FAILED: nodes_rodin.py
# IMPORT FAILED: nodes_gemini.py
#
# This issue might be caused by new missing dependencies added the last time you updated ComfyUI.
# Please do a: pip install -r requirements.txt
#
# WARNING: some comfy_extras/ nodes did not import correctly. This may be because they are missing some dependencies.
#
# IMPORT FAILED: nodes_audio.py
# IMPORT FAILED: nodes_lt.py
# IMPORT FAILED: nodes_load_3d.py
# IMPORT FAILED: nodes_video.py
#
# This issue might be caused by new missing dependencies added the last time you updated ComfyUI.
# Please do a: pip install -r requirements.txt
#
# ------------------------------------------------------------------------
# Error importing dependencies: No module named 'alembic'
# Please install the updated requirements.txt file by running:
# /usr/bin/python3 -m pip install -r /content/drive/MyDrive/ComfyUI/requirements.txt
# If you are on the portable package you can run: update\update_comfyui.bat to solve this problem.
# This error is happening because ComfyUI now uses a local sqlite database.
# ------------------------------------------------------------------------
# ********** ERROR ***********
#
# comfyui-workflow-templates is not installed.
#
# Please install the updated requirements.txt file by running:
# /usr/bin/python3 -m pip install -r /content/drive/MyDrive/ComfyUI/requirements.txt
# If you are on the portable package you can run: update\update_comfyui.bat to solve this problem.
#
# This error is happening because the ComfyUI frontend is no longer shipped as part of the main repo but as a pip package instead.
#
# ********** ERROR ***********
# comfyui-embedded-docs package not found
# ------------------------------------------------------------------------
# Error importing dependencies: No module named 'alembic'
# Please install the updated requirements.txt file by running:
# /usr/bin/python3 -m pip install -r /content/drive/MyDrive/ComfyUI/requirements.txt
# If you are on the portable package you can run: update\update_comfyui.bat to solve this problem.
# This error is happening because ComfyUI now uses a local sqlite database.
# ------------------------------------------------------------------------
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
#
# ComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)
#
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# FETCH ComfyRegistry Data: 5/92
# This is the URL to access ComfyUI: https://modular-consumption-per-toolbar.trycloudflare.com                                 |
# FETCH ComfyRegistry Data: 10/92
# FETCH ComfyRegistry Data: 15/92
# FETCH ComfyRegistry Data: 20/92
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
#
# Stopped server
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/main.py", line 356, in <module>
#     event_loop.run_until_complete(x)
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1898, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/main.py", line 358, in <module>
#     logging.info("\nStopped server")
#   File "/usr/lib/python3.11/logging/__init__.py", line 2141, in info
#     root.info(msg, *args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1489, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1634, in _log
#     self.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1644, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1706, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 978, in handle
#     self.emit(record)
#   File "/content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/prestartup_script.py", line 427, in emit
#     stderr_wrapper.sync_write(message+'\n', file_only=True)
#   File "/content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/prestartup_script.py", line 343, in sync_write
#     log_file.flush()
# KeyboardInterrupt
# Cannot connect to comfyregistry.
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json[ComfyUI-Manager] Due to a network error, switching to local mode.
# => custom-node-list.json
# => cannot schedule new futures after shutdown
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.

# %%
# !wget -P ~ https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i ~/cloudflared-linux-amd64.deb
# !pip install -r requirements.txt

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
# Out:
# --2025-07-21 05:08:20--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.7.0/cloudflared-linux-amd64.deb [following]
# --2025-07-21 05:08:20--  https://github.com/cloudflare/cloudflared/releases/download/2025.7.0/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/71a18481-c0d4-48a3-92f7-c052c62a8b60?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-21T05%3A56%3A22Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-21T04%3A55%3A40Z&ske=2025-07-21T05%3A56%3A22Z&sks=b&skv=2018-11-09&sig=9ZdK%2Bkm0alJtfDx6QkSqNAiQq7yvauL%2BTbbpmLk%2F6Z4%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MzA3NDgwMCwibmJmIjoxNzUzMDc0NTAwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.sBW5lis_bIRinul0sH7_Usa73HcVaQ-G_QYjZKBIHZ4&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream [following]
# --2025-07-21 05:08:20--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/71a18481-c0d4-48a3-92f7-c052c62a8b60?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-21T05%3A56%3A22Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64.deb&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-21T04%3A55%3A40Z&ske=2025-07-21T05%3A56%3A22Z&sks=b&skv=2018-11-09&sig=9ZdK%2Bkm0alJtfDx6QkSqNAiQq7yvauL%2BTbbpmLk%2F6Z4%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MzA3NDgwMCwibmJmIjoxNzUzMDc0NTAwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.sBW5lis_bIRinul0sH7_Usa73HcVaQ-G_QYjZKBIHZ4&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64.deb&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20166246 (19M) [application/octet-stream]
# Saving to: ‘/root/cloudflared-linux-amd64.deb.2’
#
# cloudflared-linux-a 100%[===================>]  19.23M  --.-KB/s    in 0.1s
#
# 2025-07-21 05:08:20 (158 MB/s) - ‘/root/cloudflared-linux-amd64.deb.2’ saved [20166246/20166246]
#
# (Reading database ... 126285 files and directories currently installed.)
# Preparing to unpack .../cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2025.7.0) over (2025.7.0) ...
# Setting up cloudflared (2025.7.0) ...
# Processing triggers for man-db (2.10.2-1) ...
# Requirement already satisfied: comfyui-frontend-package==1.23.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (1.23.4)
# Collecting comfyui-workflow-templates==0.1.39 (from -r requirements.txt (line 2))
#   Downloading comfyui_workflow_templates-0.1.39-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 2.2 MB/s eta 0:00:00
# Collecting comfyui-embedded-docs==0.2.4 (from -r requirements.txt (line 3))
#   Downloading comfyui_embedded_docs-0.2.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.6.0+cu124)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (0.2.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (0.8.1)
# Requirement already satisfied: transformers>=4.37.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (4.53.2)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (0.21.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: safetensors>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (0.5.3)
# Requirement already satisfied: aiohttp>=3.11.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (3.11.15)
# Requirement already satisfied: yarl>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (1.20.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (6.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (5.9.5)
# Collecting alembic (from -r requirements.txt (line 21))
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (2.0.41)
# Requirement already satisfied: kornia>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (0.8.1)
# Requirement already satisfied: spandrel in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (0.4.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (0.13.1)
# Collecting av>=14.2.0 (from -r requirements.txt (line 28))
#   Downloading av-15.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (2.11.7)
# Collecting pydantic-settings~=2.0 (from -r requirements.txt (line 30))
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.11/dist-packages (from torchsde->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (0.33.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.37.2->-r requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.11.8->-r requirements.txt (line 14)) (0.3.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl>=1.18.0->-r requirements.txt (line 15)) (3.10)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic->-r requirements.txt (line 21)) (1.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy->-r requirements.txt (line 22)) (3.2.3)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.11/dist-packages (from kornia>=0.7.1->-r requirements.txt (line 25)) (0.1.9)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile->-r requirements.txt (line 27)) (1.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->-r requirements.txt (line 29)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->-r requirements.txt (line 29)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->-r requirements.txt (line 29)) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings~=2.0->-r requirements.txt (line 30))
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile->-r requirements.txt (line 27)) (2.22)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.37.2->-r requirements.txt (line 10)) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.37.2->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.37.2->-r requirements.txt (line 10)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.37.2->-r requirements.txt (line 10)) (2025.7.14)
# Downloading comfyui_workflow_templates-0.1.39-py3-none-any.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 13.6 MB/s eta 0:00:00
# Downloading comfyui_embedded_docs-0.2.4-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.9 MB/s eta 0:00:00
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 22.8 MB/s eta 0:00:00
# Downloading av-15.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 17.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, comfyui-workflow-templates, comfyui-embedded-docs, av, alembic, pydantic-settings
# Successfully installed alembic-1.16.4 av-15.0.0 comfyui-embedded-docs-0.2.4 comfyui-workflow-templates-0.1.39 pydantic-settings-2.10.1 python-dotenv-1.1.1
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-21 05:08:33.224
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.6 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.44
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# ### Loading: ComfyUI-Manager (V3.34.1)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.44-32-g7d627f76 | Released on '2025-07-20'
#
# Import times for custom nodes:
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# No target revision found.
#
# ComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)
#
# FETCH ComfyRegistry Data: 5/92
# This is the URL to access ComfyUI: https://lock-hiv-essays-nitrogen.trycloudflare.com                                        |
# FETCH ComfyRegistry Data: 10/92
# FETCH ComfyRegistry Data: 15/92
# FETCH ComfyRegistry Data: 20/92
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
# FETCH ComfyRegistry Data: 65/92
# FETCH ComfyRegistry Data: 70/92
# FETCH ComfyRegistry Data: 75/92
# FETCH ComfyRegistry Data: 80/92
# FETCH ComfyRegistry Data: 85/92
# FETCH ComfyRegistry Data: 90/92
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/1514988643_custom-node-list.json [DONE]
# Using Python 3.11.13 environment at: /usr
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/1514988643_custom-node-list.json [DONE]
# [ComfyUI-Manager] Updating ComfyUI: nightly -> v0.3.44
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/glob/manager_core.py", line 2531, in update_to_stable_comfyui
#     repo.git.checkout(latest_tag)
#   File "/usr/local/lib/python3.11/dist-packages/git/cmd.py", line 986, in <lambda>
#     return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/git/cmd.py", line 1599, in _call_process
#     return self.execute(call, **exec_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/git/cmd.py", line 1389, in execute
#     raise GitCommandError(redacted_command, status, stderr_value, stdout_value)
# git.exc.GitCommandError: Cmd('git') failed due to: exit code(1)
#   cmdline: git checkout v0.3.44
#   stderr: 'error: Your local changes to the following files would be overwritten by checkout:
# 	.ci/windows_base_files/README_VERY_IMPORTANT.txt
# Please commit your changes or stash them before you switch branches.
# Aborting'
# ComfyUI update failed
# Updating: comfyui-manager
# [ComfyUI-Manager] Queued works are completed.
# {'update-comfyui': 1, 'update-main': 1}
#
# After restarting ComfyUI, please refresh the browser.
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/746607195_github-stats.json [DONE]
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extras.json [DONE]
# [ComfyUI-Manager] Updating ComfyUI: nightly -> v0.3.44
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager/glob/manager_core.py", line 2531, in update_to_stable_comfyui
#     repo.git.checkout(latest_tag)
#   File "/usr/local/lib/python3.11/dist-packages/git/cmd.py", line 986, in <lambda>
#     return lambda *args, **kwargs: self._call_process(name, *args, **kwargs)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/git/cmd.py", line 1599, in _call_process
#     return self.execute(call, **exec_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/git/cmd.py", line 1389, in execute
#     raise GitCommandError(redacted_command, status, stderr_value, stdout_value)
# git.exc.GitCommandError: Cmd('git') failed due to: exit code(1)
#   cmdline: git checkout v0.3.44
#   stderr: 'error: Your local changes to the following files would be overwritten by checkout:
# 	.ci/windows_base_files/README_VERY_IMPORTANT.txt
# Please commit your changes or stash them before you switch branches.
# Aborting'
# ComfyUI update failed
#
# [ComfyUI-Manager] Queued works are completed.
# {'update-comfyui': 1}
#
# After restarting ComfyUI, please refresh the browser.
# [ComfyUI-Manager] The ComfyRegistry cache update is still in progress, so an outdated cache is being used.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/1514988643_custom-node-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/746607195_github-stats.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/832903789_extras.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/1742899825_extension-node-map.json [DONE]
# 100% 32.8k/32.8k [00:00<00:00, 14.6MB/s]
# Extracted zip file to /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-GGUF
# Install: pip packages
# Using Python 3.11.13 environment at: /usr
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'gguf>=0.13.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 4 packages in 229ms
# [!] Prepared 1 package in 43ms
# [!] Installed 1 package in 7ms
# [!]  + gguf==0.17.1
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'sentencepiece']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'protobuf']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 8ms
# Using Python 3.11.13 environment at: /usr
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--dont-print-server']
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-21 05:15:49.462
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.6 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.44
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# ### Loading: ComfyUI-Manager (V3.34.1)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.44-32-g7d627f76 | Released on '2025-07-20'
# ComfyUI-GGUF: Partial torch compile only, consider updating pytorch
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
#
# Import times for custom nodes:
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-GGUF
#    0.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# No target revision found.
# FETCH ComfyRegistry Data: 5/92
# FETCH ComfyRegistry Data: 10/92
# FETCH ComfyRegistry Data: 15/92
# FETCH ComfyRegistry Data: 20/92
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
# FETCH ComfyRegistry Data: 65/92
# FETCH ComfyRegistry Data: 70/92
# FETCH ComfyRegistry Data: 75/92
# FETCH ComfyRegistry Data: 80/92
# FETCH ComfyRegistry Data: 85/92
# FETCH ComfyRegistry Data: 90/92
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# 100% 24.7M/24.7M [00:00<00:00, 144MB/s]
# Extracted zip file to /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-kjnodes
# Install: pip packages
# Using Python 3.11.13 environment at: /usr
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pillow>=10.3.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 10ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scipy']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 10ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'color-matcher']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 15 packages in 234ms
# [!] Downloading color-matcher (1.7MiB)
# [!]  Downloading color-matcher
# [!] Prepared 2 packages in 90ms
# [!] Installed 2 packages in 7ms
# [!]  + color-matcher==0.6.0
# [!]  + ddt==1.7.2
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'matplotlib']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'huggingface_hub']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 11ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'mss']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 1 package in 98ms
# [!] Prepared 1 package in 23ms
# [!] Installed 1 package in 3ms
# [!]  + mss==10.0.0
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'opencv-python']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 10ms
# Using Python 3.11.13 environment at: /usr
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
# 100% 113k/113k [00:00<00:00, 32.3MB/s]
# Extracted zip file to /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-rmbg
# Install: pip packages
# [ComfyUI-Manager] skip black listed pip installation: 'torch>=2.0.0'
# [ComfyUI-Manager] skip black listed pip installation: 'torchvision>=0.15.0'
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'Pillow>=9.0.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 14ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numpy>=1.22.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 13ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'huggingface-hub>=0.19.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 16ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'transformers>=4.35.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 21ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'safetensors>=0.3.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 15ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'transparent-background>=1.2.4']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 61 packages in 1.45s
# [!]    Building wget==3.2
# [!]       Built wget==3.2
# [!] Prepared 3 packages in 301ms
# [!] Installed 3 packages in 8ms
# [!]  + pymatting==1.1.14
# [!]  + transparent-background==1.3.4
# [!]  + wget==3.2
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'tqdm>=4.65.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 13ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'segment-anything>=1.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 1 package in 91ms
# [!] Prepared 1 package in 26ms
# [!] Installed 1 package in 2ms
# [!]  + segment-anything==1.0
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'groundingdino-py>=0.4.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 56 packages in 983ms
# [!]    Building groundingdino-py==0.4.0
# [!]       Built groundingdino-py==0.4.0
# [!] Prepared 4 packages in 265ms
# [!] Installed 4 packages in 7ms
# [!]  + addict==2.4.0
# [!]  + groundingdino-py==0.4.0
# [!]  + supervision==0.6.0
# [!]  + yapf==0.43.0
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'opencv-python>=4.7.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 10ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'scipy>=1.10.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 9ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'onnxruntime>=1.15.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 9 packages in 195ms
# [!] Downloading onnxruntime (15.7MiB)
# [!]  Downloading onnxruntime
# [!] Prepared 3 packages in 293ms
# [!] Installed 3 packages in 10ms
# [!]  + coloredlogs==15.0.1
# [!]  + humanfriendly==10.0
# [!]  + onnxruntime==1.22.1
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'onnxruntime-gpu>=1.15.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 9 packages in 96ms
# [!] Downloading onnxruntime-gpu (270.1MiB)
# [!]  Downloading onnxruntime-gpu
# [!] Prepared 1 package in 3.73s
# [!] Installed 1 package in 44ms
# [!]  + onnxruntime-gpu==1.22.0
# Using Python 3.11.13 environment at: /usr
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
# 100% 60.7k/60.7k [00:00<00:00, 37.2MB/s]
# Extracted zip file to /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_essentials
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'numba']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 8ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'colour-science']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 6 packages in 98ms
# [!] Downloading colour-science (2.4MiB)
# [!]  Downloading colour-science
# [!] Prepared 1 package in 156ms
# [!] Installed 1 package in 15ms
# [!]  + colour-science==0.4.6
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'rembg']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 28 packages in 188ms
# [!] Prepared 1 package in 29ms
# [!] Installed 1 package in 3ms
# [!]  + rembg==2.0.67
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'pixeloe']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Resolved 30 packages in 106ms
# [!]    Building pixeloe==0.1.4
# [!]       Built pixeloe==0.1.4
# [!] Prepared 1 package in 764ms
# [!] Installed 1 package in 2ms
# [!]  + pixeloe==0.1.4
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'transparent-background']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 15ms
# Using Python 3.11.13 environment at: /usr
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
# 100% 6.97M/6.97M [00:00<00:00, 137MB/s]
# Extracted zip file to /content/drive/MyDrive/ComfyUI/custom_nodes/images-grid-comfy-plugin
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
# 100% 8.84M/8.84M [00:00<00:00, 76.5MB/s]
# Extracted zip file to /content/drive/MyDrive/ComfyUI/custom_nodes/teacache
# Install: pip packages
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'einops >= 0.7.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 13ms
#
# ## ComfyUI-Manager: EXECUTE => ['/usr/bin/python3', '-m', 'uv', 'pip',
# 'install', 'diffusers >= 0.31.0']
# [!] Using Python 3.11.13 environment at: /usr
# [!] Audited 1 package in 16ms
# Using Python 3.11.13 environment at: /usr
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--dont-print-server']
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-21 05:17:57.758
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.7 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.44
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# ### Loading: ComfyUI-Manager (V3.34.1)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.44-32-g7d627f76 | Released on '2025-07-20'
# ComfyUI-GGUF: Partial torch compile only, consider updating pytorch
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# 2025-07-21 05:18:08.083235: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753075088.413645    3667 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753075088.499749    3667 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-21 05:18:09.171428: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# FETCH ComfyRegistry Data: 5/92
# NumExpr defaulting to 2 threads.
# FETCH ComfyRegistry Data: 10/92
# FETCH ComfyRegistry Data: 15/92
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [ComfyUI-RMBG] v2.5.0 | 28 nodes Loaded
# FETCH ComfyRegistry Data: 20/92
#
# Import times for custom nodes:
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-GGUF
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/images-grid-comfy-plugin
#    0.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_essentials
#    0.5 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#    0.6 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-kjnodes
#    2.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/teacache
#   15.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-rmbg
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# No target revision found.
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
# FETCH ComfyRegistry Data: 65/92
# FETCH ComfyRegistry Data: 70/92
# FETCH ComfyRegistry Data: 75/92
# FETCH ComfyRegistry Data: 80/92
# FETCH ComfyRegistry Data: 85/92
# FETCH ComfyRegistry Data: 90/92
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# [ComfyUI-Manager] Installation failed:
# ignored: installing 'comfyui-manager'
#
# [ComfyUI-Manager] Queued works are completed.
# {'install': 1}
#
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--dont-print-server']
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-21 05:20:04.918
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    0.7 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.44
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# ### Loading: ComfyUI-Manager (V3.34.1)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.44-32-g7d627f76 | Released on '2025-07-20'
# ComfyUI-GGUF: Partial torch compile only, consider updating pytorch
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# 2025-07-21 05:20:13.084646: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753075213.117402    3667 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753075213.127740    3667 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# NumExpr defaulting to 2 threads.
# FETCH ComfyRegistry Data: 5/92
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [ComfyUI-RMBG] v2.5.0 | 28 nodes Loaded
#
# Import times for custom nodes:
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    0.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/images-grid-comfy-plugin
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_essentials
#    0.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-GGUF
#    0.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-kjnodes
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#    1.5 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/teacache
#    6.7 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-rmbg
#
# FETCH ComfyRegistry Data: 10/92
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# No target revision found.
# FETCH ComfyRegistry Data: 15/92
# FETCH ComfyRegistry Data: 20/92
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
# FETCH ComfyRegistry Data: 65/92
# FETCH ComfyRegistry Data: 70/92
# FETCH ComfyRegistry Data: 75/92
# FETCH ComfyRegistry Data: 80/92
# FETCH ComfyRegistry Data: 85/92
# FETCH ComfyRegistry Data: 90/92
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# Install model 'city96/flux1-schnell-Q8_0.gguf' from 'https://huggingface.co/city96/FLUX.1-schnell-gguf/resolve/main/flux1-schnell-Q8_0.gguf' into '/content/drive/MyDrive/ComfyUI/models/diffusion_models/FLUX1/flux1-schnell-Q8_0.gguf'
#  18% 2.29G/12.7G [00:21<00:59, 175MB/s]FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# 100% 12.7G/12.7G [02:22<00:00, 89.3MB/s]
#
# [ComfyUI-Manager] Queued works are completed.
# {'install-model': 1}
#
# After restarting ComfyUI, please refresh the browser.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# Install model 'city96/flux1-dev-Q6_K.gguf' from 'https://huggingface.co/city96/FLUX.1-dev-gguf/resolve/main/flux1-dev-Q6_K.gguf' into '/content/drive/MyDrive/ComfyUI/models/diffusion_models/FLUX1/flux1-dev-Q6_K.gguf'
#  28% 2.79G/9.86G [00:26<02:24, 49.0MB/s] [DONE]
# 100% 9.86G/9.86G [01:41<00:00, 96.8MB/s]
#
# [ComfyUI-Manager] Queued works are completed.
# {'install-model': 1}
#
# After restarting ComfyUI, please refresh the browser.
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# Install model 'city96/t5-v1_1-xxl-encoder-Q8_0.gguf' from 'https://huggingface.co/city96/t5-v1_1-xxl-encoder-gguf/resolve/main/t5-v1_1-xxl-encoder-Q8_0.gguf' into '/content/drive/MyDrive/ComfyUI/models/text_encoders/t5/t5-v1_1-xxl-encoder-Q8_0.gguf'
# 100% 5.06G/5.06G [00:42<00:00, 119MB/s]
#
# [ComfyUI-Manager] Queued works are completed.
# {'install-model': 1}
#
# After restarting ComfyUI, please refresh the browser.
# ...
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy.core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
#
# Prompt executed in 19.24 seconds
# got prompt
# !!! Exception during processing !!! Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy.core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 427, in execute
#     output_data, output_ui, has_subgraph, has_pending_tasks = await get_output_data(prompt_id, unique_id, obj, input_data_all, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb)
#                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 270, in get_output_data
#     return_values = await _async_map_node_over_list(prompt_id, unique_id, obj, input_data_all, obj.FUNCTION, allow_interrupt=True, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 244, in _async_map_node_over_list
#     await process_inputs(input_dict, i)
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 232, in process_inputs
#     result = f(**inputs)
#              ^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 573, in load_checkpoint
#     out = comfy.sd.load_checkpoint_guess_config(ckpt_path, output_vae=True, output_clip=True, embedding_directory=folder_paths.get_folder_paths("embeddings"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/comfy/sd.py", line 1012, in load_checkpoint_guess_config
#     sd, metadata = comfy.utils.load_torch_file(ckpt_path, return_metadata=True)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/comfy/utils.py", line 82, in load_torch_file
#     pl_sd = torch.load(ckpt, map_location=device, weights_only=True, **torch_args)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1470, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy.core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
#
# Prompt executed in 20.36 seconds
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# FETCH DATA from: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/cache/4245046894_model-list.json [DONE]
# Install model 'v2-1_768-ema-pruned.safetensors' from 'https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors' into '/content/drive/MyDrive/ComfyUI/models/checkpoints/SD2.1/v2-1_768-ema-pruned.safetensors'
# 100% 5.21G/5.21G [01:12<00:00, 71.7MB/s]
#
# [ComfyUI-Manager] Queued works are completed.
# {'install-model': 1}
#
# After restarting ComfyUI, please refresh the browser.
#
# Restarting... [Legacy Mode]
#
#
# Command: ['/usr/bin/python3', 'main.py', '--dont-print-server']
# [START] Security scan
# Using Python 3.11.13 environment at: /usr
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2025-07-21 05:33:56.900
# ** Platform: Linux
# ** Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/drive/MyDrive/ComfyUI
# ** ComfyUI Base Folder Path: /content/drive/MyDrive/ComfyUI
# ** User directory: /content/drive/MyDrive/ComfyUI/user
# ** ComfyUI-Manager config path: /content/drive/MyDrive/ComfyUI/user/default/ComfyUI-Manager/config.ini
# ** Log path: /content/drive/MyDrive/ComfyUI/user/comfyui.log
# Using Python 3.11.13 environment at: /usr
# Using Python 3.11.13 environment at: /usr
#
# Prestartup times for custom nodes:
#    1.9 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#
# Checkpoint files will always be loaded safely.
# Total VRAM 15095 MB, total RAM 12978 MB
# pytorch version: 2.6.0+cu124
# Set vram state to: NORMAL_VRAM
# Device: cuda:0 Tesla T4 : cudaMallocAsync
# Using pytorch attention
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# ComfyUI version: 0.3.44
# ComfyUI frontend version: 1.23.4
# [Prompt Server] web root: /usr/local/lib/python3.11/dist-packages/comfyui_frontend_package/static
# ### Loading: ComfyUI-Manager (V3.34.1)
# [ComfyUI-Manager] network_mode: public
# ### ComfyUI Version: v0.3.44-32-g7d627f76 | Released on '2025-07-20'
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/alter-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/model-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/github-stats.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json
# [ComfyUI-Manager] default cache updated: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/extension-node-map.json
# ComfyUI-GGUF: Partial torch compile only, consider updating pytorch
# 2025-07-21 05:35:28.080290: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753076128.164822    3667 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753076128.182962    3667 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# FETCH ComfyRegistry Data: 5/92
# FETCH ComfyRegistry Data: 10/92
# NumExpr defaulting to 2 threads.
# FETCH ComfyRegistry Data: 15/92
# FETCH ComfyRegistry Data: 20/92
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [ComfyUI-RMBG] v2.5.0 | 28 nodes Loaded
# FETCH ComfyRegistry Data: 25/92
# FETCH ComfyRegistry Data: 30/92
#
# Import times for custom nodes:
#    0.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/websocket_image_save.py
#    1.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-GGUF
#    2.1 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui_essentials
#    2.3 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/images-grid-comfy-plugin
#    2.8 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-kjnodes
#    7.5 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/teacache
#    9.0 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/ComfyUI-Manager
#   22.2 seconds: /content/drive/MyDrive/ComfyUI/custom_nodes/comfyui-rmbg
#
# Context impl SQLiteImpl.
# Will assume non-transactional DDL.
# No target revision found.
# FETCH ComfyRegistry Data: 35/92
# FETCH ComfyRegistry Data: 40/92
# FETCH ComfyRegistry Data: 45/92
# FETCH ComfyRegistry Data: 50/92
# FETCH ComfyRegistry Data: 55/92
# FETCH ComfyRegistry Data: 60/92
# FETCH ComfyRegistry Data: 65/92
# FETCH ComfyRegistry Data: 70/92
# FETCH ComfyRegistry Data: 75/92
# FETCH ComfyRegistry Data: 80/92
# got prompt
# FETCH ComfyRegistry Data: 85/92
# model weight dtype torch.float16, manual cast: None
# model_type V_PREDICTION
# FETCH ComfyRegistry Data: 90/92
# FETCH ComfyRegistry Data [DONE]
# [ComfyUI-Manager] default cache updated: https://api.comfy.org/nodes
# FETCH DATA from: https://raw.githubusercontent.com/ltdrdata/ComfyUI-Manager/main/custom-node-list.json [DONE]
# [ComfyUI-Manager] All startup tasks have been completed.
# Using pytorch attention in VAE
# Using pytorch attention in VAE
# VAE load device: cuda:0, offload device: cpu, dtype: torch.float32
# CLIP/text encoder model load device: cuda:0, offload device: cpu, current: cpu, dtype: torch.float16
# loaded diffusion model directly to GPU
# Requested to load BaseModel
# loaded completely 9.5367431640625e+25 1651.593635559082 True
# Requested to load SD2ClipModel
# loaded completely 12101.323735046386 675.263671875 True
# 100% 20/20 [00:04<00:00,  4.30it/s]
# Requested to load AutoencoderKL
# loaded completely 10027.13505935669 319.11416244506836 True
# Prompt executed in 42.21 seconds
# got prompt
# 100% 20/20 [00:02<00:00,  7.08it/s]
# Prompt executed in 3.52 seconds
# got prompt
# !!! Exception during processing !!! Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy.core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 427, in execute
#     output_data, output_ui, has_subgraph, has_pending_tasks = await get_output_data(prompt_id, unique_id, obj, input_data_all, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb)
#                                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 270, in get_output_data
#     return_values = await _async_map_node_over_list(prompt_id, unique_id, obj, input_data_all, obj.FUNCTION, allow_interrupt=True, execution_block_cb=execution_block_cb, pre_execute_cb=pre_execute_cb)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 244, in _async_map_node_over_list
#     await process_inputs(input_dict, i)
#   File "/content/drive/MyDrive/ComfyUI/execution.py", line 232, in process_inputs
#     result = f(**inputs)
#              ^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/nodes.py", line 573, in load_checkpoint
#     out = comfy.sd.load_checkpoint_guess_config(ckpt_path, output_vae=True, output_clip=True, embedding_directory=folder_paths.get_folder_paths("embeddings"))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/comfy/sd.py", line 1012, in load_checkpoint_guess_config
#     sd, metadata = comfy.utils.load_torch_file(ckpt_path, return_metadata=True)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/ComfyUI/comfy/utils.py", line 82, in load_torch_file
#     pl_sd = torch.load(ckpt, map_location=device, weights_only=True, **torch_args)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1470, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL numpy.core.multiarray.scalar was not an allowed global by default. Please use `torch.serialization.add_safe_globals([scalar])` or the `torch.serialization.safe_globals([scalar])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
#
# Prompt executed in 75.76 seconds

# %% [markdown]
# ### Run ComfyUI with localtunnel

# %%
# !npm install -g localtunnel

import subprocess
import threading
import time
import socket
import urllib.request

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
  p = subprocess.Popen(["lt", "--port", "{}".format(port)], stdout=subprocess.PIPE)
  for line in p.stdout:
    print(line.decode(), end='')


threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ### Run ComfyUI with colab iframe (use only in case the previous way with localtunnel doesn't work)
#
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the link.
#
# Note that some UI features like live image previews won't work because the colab iframe blocks websockets.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
